# %%
import numpy as np
import pandas as pd
import janitor

# %% [markdown]
# Data on nativity and citizenship by county, from ACS

# %%
nat_cit = pd.read_csv('nativity_citizenship_county.csv', skiprows=1)

# %%
nat_cit_clean = nat_cit.clean_names()
nat_cit_clean.head()
# Out:
#         geography     geographic_area_name  estimate!!total_  \
# 0  0500000US01003  Baldwin County, Alabama          261608.0
# 1  0500000US01015  Calhoun County, Alabama          116427.0
# 2  0500000US01043  Cullman County, Alabama           92604.0
# 3  0500000US01049   DeKalb County, Alabama           73122.0
# 4  0500000US01051   Elmore County, Alabama           91042.0
#
#   margin_of_error!!total_  \
# 0                   *****
# 1                   *****
# 2                   *****
# 3                   *****
# 4                   *****
#
#    estimate!!total_!!u_s_citizen_born_in_the_united_states  \
# 0                                           247172.0
# 1                                           109548.0
# 2                                            90390.0
# 3                                            67142.0
# 4                                            89124.0
#
#    margin_of_error!!total_!!u_s_citizen_born_in_the_united_states  \
# 0                                             3402.0
# 1                                             1559.0
# 2                                              725.0
# 3                                             2013.0
# 4                                              986.0
#
#    estimate!!total_!!u_s_citizen_born_in_puerto_rico_or_u_s_island_areas  \
# 0                                              163.0
# 1                                              269.0
# 2                                                0.0
# 3                                                0.0
# 4                                              109.0
#
#    margin_of_error!!total_!!u_s_citizen_born_in_puerto_rico_or_u_s_island_areas  \
# 0                                              247.0
# 1                                              283.0
# 2                                              213.0
# 3                                              213.0
# 4                                              104.0
#
#    estimate!!total_!!u_s_citizen_born_abroad_of_american_parent_s_  \
# 0                                             1496.0
# 1                                             1722.0
# 2                                              317.0
# 3                                              154.0
# 4                                              548.0
#
#    margin_of_error!!total_!!u_s_citizen_born_abroad_of_american_parent_s_  \
# 0                                              742.0
# 1                                              692.0
# 2                                              308.0
# 3                                              144.0
# 4                                              503.0
#
#    estimate!!total_!!u_s_citizen_by_naturalization  \
# 0                                           8219.0
# 1                                           2608.0
# 2                                            584.0
# 3                                            699.0
# 4                                            492.0
#
#    margin_of_error!!total_!!u_s_citizen_by_naturalization  \
# 0                                             1766.0
# 1                                             1062.0
# 2                                              481.0
# 3                                              612.0
# 4                                              397.0
#
#    estimate!!total_!!not_a_u_s_citizen  \
# 0                               4558.0
# 1                               2280.0
# 2                               1313.0
# 3                               5127.0
# 4                                769.0
#
#    margin_of_error!!total_!!not_a_u_s_citizen  unnamed_14
# 0                                      2610.0         NaN
# 1                                       970.0         NaN
# 2                                       691.0         NaN
# 3                                      1999.0         NaN
# 4                                       731.0         NaN

# %%
nat_cit_clean.drop('unnamed_14', axis=1, inplace=True)
# Out:
# /var/folders/rz/h3gzrv2j09s6d_5vmn0bglw40000gn/T/ipykernel_83730/2101964408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nat_cit_clean.drop('unnamed_14', axis=1, inplace=True)

# %% [markdown]
# What I want to do with this:
# - Clean this data
# - Merge with county-level shapefile
# - Merge with AOR shapefile
# - Merge with encounters data

# %% [markdown]
# Cleaning plan:
# - Improve column names
# - Drop NAs
# - Create columns of the proportions vs total

# %%
# drop rows with NAs
print(nat_cit_clean.isna().sum())
nat_cit_clean = nat_cit_clean.dropna()
nat_cit_clean.head()
# Out:
# geography                                                                        0
# geographic_area_name                                                             0
# estimate!!total_                                                                18
# margin_of_error!!total_                                                         18
# estimate!!total_!!u_s_citizen_born_in_the_united_states                         18
# margin_of_error!!total_!!u_s_citizen_born_in_the_united_states                  18
# estimate!!total_!!u_s_citizen_born_in_puerto_rico_or_u_s_island_areas           18
# margin_of_error!!total_!!u_s_citizen_born_in_puerto_rico_or_u_s_island_areas    18
# estimate!!total_!!u_s_citizen_born_abroad_of_american_parent_s_                 18
# margin_of_error!!total_!!u_s_citizen_born_abroad_of_american_parent_s_          18
# estimate!!total_!!u_s_citizen_by_naturalization                                 18
# margin_of_error!!total_!!u_s_citizen_by_naturalization                          18
# estimate!!total_!!not_a_u_s_citizen                                             18
# margin_of_error!!total_!!not_a_u_s_citizen                                      18
# dtype: int64
#         geography     geographic_area_name  estimate!!total_  \
# 0  0500000US01003  Baldwin County, Alabama          261608.0
# 1  0500000US01015  Calhoun County, Alabama          116427.0
# 2  0500000US01043  Cullman County, Alabama           92604.0
# 3  0500000US01049   DeKalb County, Alabama           73122.0
# 4  0500000US01051   Elmore County, Alabama           91042.0
#
#   margin_of_error!!total_  \
# 0                   *****
# 1                   *****
# 2                   *****
# 3                   *****
# 4                   *****
#
#    estimate!!total_!!u_s_citizen_born_in_the_united_states  \
# 0                                           247172.0
# 1                                           109548.0
# 2                                            90390.0
# 3                                            67142.0
# 4                                            89124.0
#
#    margin_of_error!!total_!!u_s_citizen_born_in_the_united_states  \
# 0                                             3402.0
# 1                                             1559.0
# 2                                              725.0
# 3                                             2013.0
# 4                                              986.0
#
#    estimate!!total_!!u_s_citizen_born_in_puerto_rico_or_u_s_island_areas  \
# 0                                              163.0
# 1                                              269.0
# 2                                                0.0
# 3                                                0.0
# 4                                              109.0
#
#    margin_of_error!!total_!!u_s_citizen_born_in_puerto_rico_or_u_s_island_areas  \
# 0                                              247.0
# 1                                              283.0
# 2                                              213.0
# 3                                              213.0
# 4                                              104.0
#
#    estimate!!total_!!u_s_citizen_born_abroad_of_american_parent_s_  \
# 0                                             1496.0
# 1                                             1722.0
# 2                                              317.0
# 3                                              154.0
# 4                                              548.0
#
#    margin_of_error!!total_!!u_s_citizen_born_abroad_of_american_parent_s_  \
# 0                                              742.0
# 1                                              692.0
# 2                                              308.0
# 3                                              144.0
# 4                                              503.0
#
#    estimate!!total_!!u_s_citizen_by_naturalization  \
# 0                                           8219.0
# 1                                           2608.0
# 2                                            584.0
# 3                                            699.0
# 4                                            492.0
#
#    margin_of_error!!total_!!u_s_citizen_by_naturalization  \
# 0                                             1766.0
# 1                                             1062.0
# 2                                              481.0
# 3                                              612.0
# 4                                              397.0
#
#    estimate!!total_!!not_a_u_s_citizen  \
# 0                               4558.0
# 1                               2280.0
# 2                               1313.0
# 3                               5127.0
# 4                                769.0
#
#    margin_of_error!!total_!!not_a_u_s_citizen
# 0                                      2610.0
# 1                                       970.0
# 2                                       691.0
# 3                                      1999.0
# 4                                       731.0

# %%
nat_cit_clean.columns = nat_cit_clean.columns.str.replace("total_", "", regex=False)
nat_cit_clean.columns = nat_cit_clean.columns.str.replace("!!", "_", regex=False)

# %%
nat_cit_clean.columns = nat_cit_clean.columns.str.replace("_u_s_", "", regex=False)
nat_cit_clean.columns = nat_cit_clean.columns.str.replace("the_united_states", "us", regex=False)
nat_cit_clean.columns = nat_cit_clean.columns.str.replace("__not_acitizen", "_not_a_citizen", regex=False)

# %%
nat_cit_clean.head()
# Out:
#         geography     geographic_area_name  estimate_ margin_of_error_  \
# 0  0500000US01003  Baldwin County, Alabama   261608.0            *****
# 1  0500000US01015  Calhoun County, Alabama   116427.0            *****
# 2  0500000US01043  Cullman County, Alabama    92604.0            *****
# 3  0500000US01049   DeKalb County, Alabama    73122.0            *****
# 4  0500000US01051   Elmore County, Alabama    91042.0            *****
#
#    estimate_citizen_born_in_us  margin_of_error_citizen_born_in_us  \
# 0                     247172.0                              3402.0
# 1                     109548.0                              1559.0
# 2                      90390.0                               725.0
# 3                      67142.0                              2013.0
# 4                      89124.0                               986.0
#
#    estimate_citizen_born_in_puerto_rico_orisland_areas  \
# 0                                              163.0
# 1                                              269.0
# 2                                                0.0
# 3                                                0.0
# 4                                              109.0
#
#    margin_of_error_citizen_born_in_puerto_rico_orisland_areas  \
# 0                                              247.0
# 1                                              283.0
# 2                                              213.0
# 3                                              213.0
# 4                                              104.0
#
#    estimate_citizen_born_abroad_of_american_parent_s_  \
# 0                                             1496.0
# 1                                             1722.0
# 2                                              317.0
# 3                                              154.0
# 4                                              548.0
#
#    margin_of_error_citizen_born_abroad_of_american_parent_s_  \
# 0                                              742.0
# 1                                              692.0
# 2                                              308.0
# 3                                              144.0
# 4                                              503.0
#
#    estimate_citizen_by_naturalization  \
# 0                              8219.0
# 1                              2608.0
# 2                               584.0
# 3                               699.0
# 4                               492.0
#
#    margin_of_error_citizen_by_naturalization  estimate_not_a_citizen  \
# 0                                     1766.0                  4558.0
# 1                                     1062.0                  2280.0
# 2                                      481.0                  1313.0
# 3                                      612.0                  5127.0
# 4                                      397.0                   769.0
#
#    margin_of_error_not_a_citizen
# 0                         2610.0
# 1                          970.0
# 2                          691.0
# 3                         1999.0
# 4                          731.0

# %%
def add_proportions(df, denom_col = "estimate_", prefix="estimate_", new_prefix="prop_"):
    est_cols = [col for col in df.columns
                if col.startswith(prefix) and col != denom_col]
    props = df[est_cols].div(df[denom_col], axis=0)
    props = props.rename(columns=lambda x: x.replace(prefix, new_prefix, 1))

    return df.join(props)

# %%
nat_cit_clean = add_proportions(nat_cit_clean)

# %%
nat_cit_clean.head()
# Out:
#         geography     geographic_area_name  estimate_ margin_of_error_  \
# 0  0500000US01003  Baldwin County, Alabama   261608.0            *****
# 1  0500000US01015  Calhoun County, Alabama   116427.0            *****
# 2  0500000US01043  Cullman County, Alabama    92604.0            *****
# 3  0500000US01049   DeKalb County, Alabama    73122.0            *****
# 4  0500000US01051   Elmore County, Alabama    91042.0            *****
#
#    estimate_citizen_born_in_us  margin_of_error_citizen_born_in_us  \
# 0                     247172.0                              3402.0
# 1                     109548.0                              1559.0
# 2                      90390.0                               725.0
# 3                      67142.0                              2013.0
# 4                      89124.0                               986.0
#
#    estimate_citizen_born_in_puerto_rico_orisland_areas  \
# 0                                              163.0
# 1                                              269.0
# 2                                                0.0
# 3                                                0.0
# 4                                              109.0
#
#    margin_of_error_citizen_born_in_puerto_rico_orisland_areas  \
# 0                                              247.0
# 1                                              283.0
# 2                                              213.0
# 3                                              213.0
# 4                                              104.0
#
#    estimate_citizen_born_abroad_of_american_parent_s_  \
# 0                                             1496.0
# 1                                             1722.0
# 2                                              317.0
# 3                                              154.0
# 4                                              548.0
#
#    margin_of_error_citizen_born_abroad_of_american_parent_s_  \
# 0                                              742.0
# 1                                              692.0
# 2                                              308.0
# 3                                              144.0
# 4                                              503.0
#
#    estimate_citizen_by_naturalization  \
# 0                              8219.0
# 1                              2608.0
# 2                               584.0
# 3                               699.0
# 4                               492.0
#
#    margin_of_error_citizen_by_naturalization  estimate_not_a_citizen  \
# 0                                     1766.0                  4558.0
# 1                                     1062.0                  2280.0
# 2                                      481.0                  1313.0
# 3                                      612.0                  5127.0
# 4                                      397.0                   769.0
#
#    margin_of_error_not_a_citizen  prop_citizen_born_in_us  \
# 0                         2610.0                 0.944818
# 1                          970.0                 0.940916
# 2                          691.0                 0.976092
# 3                         1999.0                 0.918219
# 4                          731.0                 0.978933
#
#    prop_citizen_born_in_puerto_rico_orisland_areas  \
# 0                                         0.000623
# 1                                         0.002310
# 2                                         0.000000
# 3                                         0.000000
# 4                                         0.001197
#
#    prop_citizen_born_abroad_of_american_parent_s_  \
# 0                                        0.005718
# 1                                        0.014790
# 2                                        0.003423
# 3                                        0.002106
# 4                                        0.006019
#
#    prop_citizen_by_naturalization  prop_not_a_citizen
# 0                        0.031417            0.017423
# 1                        0.022400            0.019583
# 2                        0.006306            0.014179
# 3                        0.009559            0.070116
# 4                        0.005404            0.008447

# %%
nat_cit_clean.to_csv('nat_cit_cleaned.csv', index=False)
